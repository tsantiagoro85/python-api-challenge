# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = {"q": city, "units": "metric", "APPID": weather_api_key}

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url, params = city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | port mathurin
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | west island
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | argo
# Processing Record 7 of Set 1 | papatowai
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | tolanaro
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | alesund
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | udachny
# Processing Record 15 of Set 1 | pangody
# Processing Record 16 of Set 1 | blackmans bay
# Processing Record 17 of Set 1 | san rafael
# Processing Record 18 of Set 1 | kursunlu
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | najaf
# Processing Record 21 of Set 1 | baruun-urt
# Processing Record 22 of Set 1 | peniche
# Processing Record 23 of Set 1 | aurad
# Processing Record 24 of Set 1 | arawa
# Processing Record 25 of Set 1 | mili
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | krasnokamensk
# Processing Record 28 of Set 1 | orapa
# Processing Record 29 of Set 1 | bac lieu
# Processing Record 30 of Set 1 | newberry
# Processing Record 31 of Set 1 | sonsorol village
# City not found. Skipping...
# Processing Record 32 of Set 1 | oualidia
# City not found. Skipping...
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | whyalla stuart
# City not found. Skipping...
# Processing Record 35 of Set 1 | stanley
# Processing Record 36 of Set 1 | olonkinbyen
# Processing Record 37 of Set 1 | puerto princesa
# Processing Record 38 of Set 1 | manadhoo
# Processing Record 39 of Set 1 | kapuskasing
# Processing Record 40 of Set 1 | cherepovets
# Processing Record 41 of Set 1 | ta`u
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | krishnanagar
# Processing Record 45 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | puerto baquerizo moreno
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | beterou
# Processing Record 50 of Set 1 | yagry
# City not found. Skipping...
# Processing Record 0 of Set 2 | fonadhoo
# City not found. Skipping...
# Processing Record 1 of Set 2 | totness
# Processing Record 2 of Set 2 | muroto-misakicho
# Processing Record 3 of Set 2 | san antonio de pale
# Processing Record 4 of Set 2 | margaret river
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | manismata
# Processing Record 8 of Set 2 | tazovsky
# Processing Record 9 of Set 2 | grytviken
# Processing Record 10 of Set 2 | puerto cabezas
# Processing Record 11 of Set 2 | quepos
# Processing Record 12 of Set 2 | qaqortoq
# Processing Record 13 of Set 2 | novodvinsk
# Processing Record 14 of Set 2 | shushtar
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | maintirano
# Processing Record 18 of Set 2 | sohar
# Processing Record 19 of Set 2 | taoudenni
# Processing Record 20 of Set 2 | calvinia
# Processing Record 21 of Set 2 | adamstown
# Processing Record 22 of Set 2 | gladstone
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | bilibino
# Processing Record 26 of Set 2 | tselina
# Processing Record 27 of Set 2 | shangrao
# Processing Record 28 of Set 2 | yanchep
# Processing Record 29 of Set 2 | sos'va
# Processing Record 30 of Set 2 | oranjemund
# Processing Record 31 of Set 2 | fort bragg
# Processing Record 32 of Set 2 | pop
# Processing Record 33 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | dali
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | badger
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | zmiyevka
# Processing Record 41 of Set 2 | vernon
# Processing Record 42 of Set 2 | la'ie
# Processing Record 43 of Set 2 | tamiahua
# Processing Record 44 of Set 2 | kabalo
# Processing Record 45 of Set 2 | vilyuchinsk
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | coahuayana de hidalgo
# Processing Record 48 of Set 2 | sandnessjoen
# Processing Record 49 of Set 2 | sitia
# Processing Record 0 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 3 | noumea
# Processing Record 2 of Set 3 | garachico
# Processing Record 3 of Set 3 | akureyri
# Processing Record 4 of Set 3 | enriquillo
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | whitehorse
# Processing Record 7 of Set 3 | salym
# Processing Record 8 of Set 3 | ghadamis
# Processing Record 9 of Set 3 | callao
# Processing Record 10 of Set 3 | porto novo
# Processing Record 11 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 12 of Set 3 | pantai cenang
# City not found. Skipping...
# Processing Record 13 of Set 3 | holualoa
# Processing Record 14 of Set 3 | nar'yan-mar
# Processing Record 15 of Set 3 | invercargill
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | jumla
# Processing Record 18 of Set 3 | zaraza
# Processing Record 19 of Set 3 | moberly
# Processing Record 20 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 21 of Set 3 | mancora
# Processing Record 22 of Set 3 | calauag
# Processing Record 23 of Set 3 | fale old settlement
# Processing Record 24 of Set 3 | pante makasar
# City not found. Skipping...
# Processing Record 25 of Set 3 | omutinskiy
# Processing Record 26 of Set 3 | port macquarie
# Processing Record 27 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 3 | happy valley-goose bay
# Processing Record 29 of Set 3 | nizhneangarsk
# Processing Record 30 of Set 3 | little cayman
# City not found. Skipping...
# Processing Record 31 of Set 3 | utrik
# Processing Record 32 of Set 3 | tadpatri
# Processing Record 33 of Set 3 | ciutadella
# Processing Record 34 of Set 3 | remire-montjoly
# Processing Record 35 of Set 3 | undurkhaan
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 3 | vikulovo
# Processing Record 39 of Set 3 | atafu village
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | miami
# Processing Record 42 of Set 3 | ust-tsilma
# Processing Record 43 of Set 3 | lethem
# Processing Record 44 of Set 3 | portland
# Processing Record 45 of Set 3 | barnesville
# Processing Record 46 of Set 3 | punta arenas
# Processing Record 47 of Set 3 | ushuaia
# Processing Record 48 of Set 3 | bulayevo
# Processing Record 49 of Set 3 | fisterra
# Processing Record 0 of Set 4 | barabai
# Processing Record 1 of Set 4 | sumberpucung
# Processing Record 2 of Set 4 | nuuk
# Processing Record 3 of Set 4 | nizhneudinsk
# Processing Record 4 of Set 4 | acapulco de juarez
# Processing Record 5 of Set 4 | sanctuary point
# Processing Record 6 of Set 4 | korla
# Processing Record 7 of Set 4 | queenstown
# Processing Record 8 of Set 4 | okhotsk
# Processing Record 9 of Set 4 | ballycastle
# Processing Record 10 of Set 4 | sinop
# Processing Record 11 of Set 4 | robore
# Processing Record 12 of Set 4 | road town
# Processing Record 13 of Set 4 | kiama
# Processing Record 14 of Set 4 | tonj
# Processing Record 15 of Set 4 | yerofey pavlovich
# Processing Record 16 of Set 4 | pacocha
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | lasalgaon
# Processing Record 19 of Set 4 | kisangani
# Processing Record 20 of Set 4 | arkhangel'sk
# Processing Record 21 of Set 4 | gadzhiyevo
# Processing Record 22 of Set 4 | tura
# Processing Record 23 of Set 4 | tsiombe
# Processing Record 24 of Set 4 | i-n-salah
# Processing Record 25 of Set 4 | kerikeri
# Processing Record 26 of Set 4 | klyuchi
# Processing Record 27 of Set 4 | barao de cocais
# Processing Record 28 of Set 4 | santiago de cao
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 31 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 32 of Set 4 | keflavik
# Processing Record 33 of Set 4 | iskateley
# Processing Record 34 of Set 4 | aykhal
# Processing Record 35 of Set 4 | syevyerodonets'k
# Processing Record 36 of Set 4 | visby
# Processing Record 37 of Set 4 | kingston
# Processing Record 38 of Set 4 | iqaluit
# Processing Record 39 of Set 4 | betio village
# Processing Record 40 of Set 4 | afaahiti
# Processing Record 41 of Set 4 | gaspe
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | berdigestyakh
# Processing Record 44 of Set 4 | hadibu
# Processing Record 45 of Set 4 | grand falls-windsor
# Processing Record 46 of Set 4 | polyarnyy
# Processing Record 47 of Set 4 | magadan
# Processing Record 48 of Set 4 | thakhek
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 0 of Set 5 | nova sintra
# Processing Record 1 of Set 5 | tuzha
# Processing Record 2 of Set 5 | debre werk'
# Processing Record 3 of Set 5 | isafjordur
# Processing Record 4 of Set 5 | homer
# Processing Record 5 of Set 5 | la passe
# Processing Record 6 of Set 5 | beledweyne
# Processing Record 7 of Set 5 | ribeira grande
# Processing Record 8 of Set 5 | forres
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | winburg
# Processing Record 11 of Set 5 | berezovyy
# Processing Record 12 of Set 5 | santa cruz
# Processing Record 13 of Set 5 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 14 of Set 5 | krasnoarmeysk
# Processing Record 15 of Set 5 | ellsworth
# Processing Record 16 of Set 5 | san ignacio
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | neftegorsk
# Processing Record 19 of Set 5 | yen vinh
# Processing Record 20 of Set 5 | chonchi
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | colonia
# Processing Record 23 of Set 5 | nangomba
# Processing Record 24 of Set 5 | broome
# Processing Record 25 of Set 5 | ocean shores
# Processing Record 26 of Set 5 | enewetak
# Processing Record 27 of Set 5 | tamanrasset
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | sabha
# Processing Record 30 of Set 5 | mahuta
# Processing Record 31 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 32 of Set 5 | sucre
# Processing Record 33 of Set 5 | lisala
# Processing Record 34 of Set 5 | danilovka
# Processing Record 35 of Set 5 | paramirim
# Processing Record 36 of Set 5 | pont rouge
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | constantia
# Processing Record 39 of Set 5 | acajutla
# Processing Record 40 of Set 5 | itoman
# Processing Record 41 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 42 of Set 5 | kijang
# Processing Record 43 of Set 5 | karratha
# Processing Record 44 of Set 5 | vadso
# Processing Record 45 of Set 5 | vila do maio
# Processing Record 46 of Set 5 | severo-yeniseyskiy
# Processing Record 47 of Set 5 | cannonvale
# Processing Record 48 of Set 5 | khartoum
# Processing Record 49 of Set 5 | al bawiti
# Processing Record 0 of Set 6 | heniches'k
# Processing Record 1 of Set 6 | yarmouth
# Processing Record 2 of Set 6 | tarawa
# Processing Record 3 of Set 6 | kamba
# Processing Record 4 of Set 6 | jiayuguan
# Processing Record 5 of Set 6 | playa del ingles
# Processing Record 6 of Set 6 | buenaventura
# Processing Record 7 of Set 6 | shanhecun
# Processing Record 8 of Set 6 | nova vicosa
# Processing Record 9 of Set 6 | tazacorte
# Processing Record 10 of Set 6 | xilin hot
# Processing Record 11 of Set 6 | hassi messaoud
# Processing Record 12 of Set 6 | crane
# Processing Record 13 of Set 6 | harper
# Processing Record 14 of Set 6 | nazyvayevsk
# Processing Record 15 of Set 6 | laojunmiao
# Processing Record 16 of Set 6 | charters towers
# Processing Record 17 of Set 6 | kimberley
# Processing Record 18 of Set 6 | ambon
# Processing Record 19 of Set 6 | yelizovo
# Processing Record 20 of Set 6 | hawaiian paradise park
# Processing Record 21 of Set 6 | juneau
# Processing Record 22 of Set 6 | labytnangi
# Processing Record 23 of Set 6 | maros
# City not found. Skipping...
# Processing Record 24 of Set 6 | east ballina
# Processing Record 25 of Set 6 | ishigaki
# Processing Record 26 of Set 6 | kudahuvadhoo
# Processing Record 27 of Set 6 | valparaiso
# Processing Record 28 of Set 6 | saipan
# Processing Record 29 of Set 6 | saraqib
# Processing Record 30 of Set 6 | khandyga
# Processing Record 31 of Set 6 | glendora
# Processing Record 32 of Set 6 | port augusta
# Processing Record 33 of Set 6 | otaru
# Processing Record 34 of Set 6 | pachino
# Processing Record 35 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 36 of Set 6 | makubetsu
# Processing Record 37 of Set 6 | tafuna
# Processing Record 38 of Set 6 | afif
# Processing Record 39 of Set 6 | usogorsk
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | dryden
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | nikko
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | poso
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | kone
# Processing Record 48 of Set 6 | aasiaat
# Processing Record 49 of Set 6 | shingu
# Processing Record 0 of Set 7 | shasta lake
# Processing Record 1 of Set 7 | quellon
# Processing Record 2 of Set 7 | alotau
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | mar del plata
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | sayansk
# Processing Record 7 of Set 7 | letterkenny
# Processing Record 8 of Set 7 | port saint john's
# Processing Record 9 of Set 7 | wailua homesteads
# Processing Record 10 of Set 7 | kainantu
# Processing Record 11 of Set 7 | angul
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | kourou
# Processing Record 14 of Set 7 | vicksburg
# Processing Record 15 of Set 7 | rio grande
# Processing Record 16 of Set 7 | praia da vitoria
# Processing Record 17 of Set 7 | sake
# Processing Record 18 of Set 7 | gizo
# Processing Record 19 of Set 7 | dudinka
# Processing Record 20 of Set 7 | rongelap
# Processing Record 21 of Set 7 | tutoia
# Processing Record 22 of Set 7 | mahibadhoo
# Processing Record 23 of Set 7 | ohara
# Processing Record 24 of Set 7 | ilave
# Processing Record 25 of Set 7 | birobidzhan
# Processing Record 26 of Set 7 | barcarena
# Processing Record 27 of Set 7 | east london
# Processing Record 28 of Set 7 | saint-louis
# Processing Record 29 of Set 7 | kambove
# Processing Record 30 of Set 7 | anahuac
# Processing Record 31 of Set 7 | opuwo
# Processing Record 32 of Set 7 | nemuro
# Processing Record 33 of Set 7 | port moresby
# Processing Record 34 of Set 7 | bouake
# Processing Record 35 of Set 7 | alur
# Processing Record 36 of Set 7 | narrabri
# Processing Record 37 of Set 7 | malpica
# Processing Record 38 of Set 7 | tynda
# Processing Record 39 of Set 7 | san andres
# Processing Record 40 of Set 7 | ringkobing
# Processing Record 41 of Set 7 | bartlesville
# Processing Record 42 of Set 7 | pathein
# Processing Record 43 of Set 7 | al jabin
# Processing Record 44 of Set 7 | argostolion
# Processing Record 45 of Set 7 | leua
# Processing Record 46 of Set 7 | papao
# Processing Record 47 of Set 7 | greymouth
# Processing Record 48 of Set 7 | puerto aysen
# Processing Record 49 of Set 7 | xam nua
# Processing Record 0 of Set 8 | castillos
# Processing Record 1 of Set 8 | hovd
# Processing Record 2 of Set 8 | preobrazheniye
# Processing Record 3 of Set 8 | xapuri
# Processing Record 4 of Set 8 | akkol'
# Processing Record 5 of Set 8 | dhrosia
# City not found. Skipping...
# Processing Record 6 of Set 8 | tofol
# Processing Record 7 of Set 8 | uturoa
# Processing Record 8 of Set 8 | tralee
# Processing Record 9 of Set 8 | jamestown
# Processing Record 10 of Set 8 | penalva
# Processing Record 11 of Set 8 | togur
# Processing Record 12 of Set 8 | tidjikja
# Processing Record 13 of Set 8 | kill devil hills
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | bonthe
# Processing Record 16 of Set 8 | jhusi
# Processing Record 17 of Set 8 | antalaha
# Processing Record 18 of Set 8 | newman
# Processing Record 19 of Set 8 | piton saint-leu
# Processing Record 20 of Set 8 | sitka
# Processing Record 21 of Set 8 | shchigry
# Processing Record 22 of Set 8 | umm kaddadah
# Processing Record 23 of Set 8 | pitanga
# Processing Record 24 of Set 8 | coremas
# Processing Record 25 of Set 8 | bandiagara
# Processing Record 26 of Set 8 | paita
# Processing Record 27 of Set 8 | fortaleza
# Processing Record 28 of Set 8 | ararat
# Processing Record 29 of Set 8 | champoton
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | bei'an
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | chernyshevskiy
# Processing Record 34 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 35 of Set 8 | rwamagana
# Processing Record 36 of Set 8 | saudarkrokur
# Processing Record 37 of Set 8 | touros
# Processing Record 38 of Set 8 | itaituba
# Processing Record 39 of Set 8 | springbok
# Processing Record 40 of Set 8 | bikenibeu village
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | choibalsan
# Processing Record 43 of Set 8 | labrador city
# Processing Record 44 of Set 8 | balykshi
# Processing Record 45 of Set 8 | bodaybo
# Processing Record 46 of Set 8 | naha
# Processing Record 47 of Set 8 | as sulayyil
# Processing Record 48 of Set 8 | nagqu
# Processing Record 49 of Set 8 | desaguadero
# Processing Record 0 of Set 9 | dolinsk
# Processing Record 1 of Set 9 | bubaque
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | westville
# Processing Record 4 of Set 9 | morehead city
# Processing Record 5 of Set 9 | hasaki
# Processing Record 6 of Set 9 | karamay
# Processing Record 7 of Set 9 | khagrachhari
# Processing Record 8 of Set 9 | kruisfontein
# Processing Record 9 of Set 9 | nuku'alofa
# Processing Record 10 of Set 9 | mme-bafumen
# Processing Record 11 of Set 9 | waddan
# Processing Record 12 of Set 9 | maceio
# Processing Record 13 of Set 9 | nueva esperanza
# Processing Record 14 of Set 9 | luneville
# Processing Record 15 of Set 9 | coquimbo
# Processing Record 16 of Set 9 | sao raimundo nonato
# Processing Record 17 of Set 9 | duncan town
# City not found. Skipping...
# Processing Record 18 of Set 9 | freetown
# Processing Record 19 of Set 9 | yuzhno-kurilsk
# Processing Record 20 of Set 9 | tamazunchale
# Processing Record 21 of Set 9 | saint-philippe
# Processing Record 22 of Set 9 | east foothills
# Processing Record 23 of Set 9 | palmer
# Processing Record 24 of Set 9 | grande prairie
# Processing Record 25 of Set 9 | campo maior
# Processing Record 26 of Set 9 | lloydminster
# Processing Record 27 of Set 9 | pitimbu
# Processing Record 28 of Set 9 | khorixas
# Processing Record 29 of Set 9 | champerico
# Processing Record 30 of Set 9 | kailua-kona
# Processing Record 31 of Set 9 | neukirch/lausitz
# Processing Record 32 of Set 9 | pudasjarvi
# Processing Record 33 of Set 9 | sishilichengzi
# City not found. Skipping...
# Processing Record 34 of Set 9 | vorgashor
# Processing Record 35 of Set 9 | ierapetra
# Processing Record 36 of Set 9 | malpe
# Processing Record 37 of Set 9 | staroshcherbinovskaya
# Processing Record 38 of Set 9 | waingapu
# Processing Record 39 of Set 9 | sokoni
# Processing Record 40 of Set 9 | argos orestiko
# Processing Record 41 of Set 9 | manay
# Processing Record 42 of Set 9 | puerto leguizamo
# Processing Record 43 of Set 9 | senak'i
# Processing Record 44 of Set 9 | nassau
# Processing Record 45 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 46 of Set 9 | jiaozuo
# Processing Record 47 of Set 9 | solnechnyy
# Processing Record 48 of Set 9 | kalabo
# Processing Record 49 of Set 9 | alta
# Processing Record 0 of Set 10 | bajos de haina
# Processing Record 1 of Set 10 | komsomolets
# Processing Record 2 of Set 10 | salalah
# Processing Record 3 of Set 10 | mossel bay
# Processing Record 4 of Set 10 | hamilton
# Processing Record 5 of Set 10 | datong
# Processing Record 6 of Set 10 | kapa'a
# Processing Record 7 of Set 10 | bobo-dioulasso
# Processing Record 8 of Set 10 | esuk oron
# Processing Record 9 of Set 10 | dickinson
# Processing Record 10 of Set 10 | hami
# Processing Record 11 of Set 10 | kuta
# Processing Record 12 of Set 10 | ravar
# Processing Record 13 of Set 10 | baluntaicun
# City not found. Skipping...
# Processing Record 14 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 15 of Set 10 | namdrik
# Processing Record 16 of Set 10 | whakatane
# Processing Record 17 of Set 10 | dalandzadgad
# Processing Record 18 of Set 10 | melendugno
# Processing Record 19 of Set 10 | senanga
# Processing Record 20 of Set 10 | lorengau
# Processing Record 21 of Set 10 | ebaye
# Processing Record 22 of Set 10 | boa vista
# Processing Record 23 of Set 10 | byaroza
# Processing Record 24 of Set 10 | guangming
# Processing Record 25 of Set 10 | gore
# Processing Record 26 of Set 10 | alice springs
# Processing Record 27 of Set 10 | mahdishahr
# Processing Record 28 of Set 10 | pandan
# Processing Record 29 of Set 10 | st. john's
# Processing Record 30 of Set 10 | pitiquito
# Processing Record 31 of Set 10 | monrovia
# Processing Record 32 of Set 10 | connell
# Processing Record 33 of Set 10 | kuzovatovo
# Processing Record 34 of Set 10 | lodwar
# Processing Record 35 of Set 10 | ugoofaaru
# Processing Record 36 of Set 10 | ciudad lazaro cardenas
# Processing Record 37 of Set 10 | magalia
# Processing Record 38 of Set 10 | sao gabriel da cachoeira
# Processing Record 39 of Set 10 | agat village
# Processing Record 40 of Set 10 | kunduz
# Processing Record 41 of Set 10 | faya-largeau
# Processing Record 42 of Set 10 | laascaanood
# Processing Record 43 of Set 10 | northam
# Processing Record 44 of Set 10 | tomatlan
# Processing Record 45 of Set 10 | olvera
# Processing Record 46 of Set 10 | cambria
# Processing Record 47 of Set 10 | island harbour
# Processing Record 48 of Set 10 | okha
# Processing Record 49 of Set 10 | prince rupert
# Processing Record 0 of Set 11 | brokopondo
# Processing Record 1 of Set 11 | manaquiri
# Processing Record 2 of Set 11 | wanning
# Processing Record 3 of Set 11 | paciran
# Processing Record 4 of Set 11 | bhag
# Processing Record 5 of Set 11 | codrington
# Processing Record 6 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 11 | tucurui
# Processing Record 8 of Set 11 | lihue
# Processing Record 9 of Set 11 | ibarreta
# Processing Record 10 of Set 11 | vicuna mackenna
# Processing Record 11 of Set 11 | kiunga
# Processing Record 12 of Set 11 | srandakan
# Processing Record 13 of Set 11 | esquel
# Processing Record 14 of Set 11 | san sebastian de la gomera
# Processing Record 15 of Set 11 | ujae
# Processing Record 16 of Set 11 | silver city
# Processing Record 17 of Set 11 | chalus
# Processing Record 18 of Set 11 | zabid
# Processing Record 19 of Set 11 | linqiong
# Processing Record 20 of Set 11 | inhambane
# Processing Record 21 of Set 11 | ostersund
# Processing Record 22 of Set 11 | namsos
# Processing Record 23 of Set 11 | mawlaik
# Processing Record 24 of Set 11 | luganville
# Processing Record 25 of Set 11 | ilam
# Processing Record 26 of Set 11 | lycksele
# Processing Record 27 of Set 11 | tuy hoa
# Processing Record 28 of Set 11 | carbonear
# Processing Record 29 of Set 11 | darwin
# Processing Record 30 of Set 11 | talghar
# Processing Record 31 of Set 11 | karbala
# Processing Record 32 of Set 11 | kabala
# Processing Record 33 of Set 11 | tweed heads
# Processing Record 34 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 35 of Set 11 | woolgoolga
# Processing Record 36 of Set 11 | ola
# Processing Record 37 of Set 11 | ar ruseris
# Processing Record 38 of Set 11 | conception bay south
# Processing Record 39 of Set 11 | mount pearl
# Processing Record 40 of Set 11 | piti village
# Processing Record 41 of Set 11 | ndioum
# Processing Record 42 of Set 11 | ormara
# Processing Record 43 of Set 11 | troitsko-pechorsk
# Processing Record 44 of Set 11 | plettenberg bay
# Processing Record 45 of Set 11 | kayyerkan
# Processing Record 46 of Set 11 | broken hill
# Processing Record 47 of Set 11 | kismayo
# Processing Record 48 of Set 11 | duba
# Processing Record 49 of Set 11 | viedma
# Processing Record 0 of Set 12 | shigony
# Processing Record 1 of Set 12 | gebeit
# Processing Record 2 of Set 12 | midvagur
# Processing Record 3 of Set 12 | impfondo
# Processing Record 4 of Set 12 | cidreira
# Processing Record 5 of Set 12 | revda
# Processing Record 6 of Set 12 | diamantino
# Processing Record 7 of Set 12 | gewane
# Processing Record 8 of Set 12 | vorkuta
# Processing Record 9 of Set 12 | maunabo
# Processing Record 10 of Set 12 | padre bernardo
# Processing Record 11 of Set 12 | chlumec nad cidlinou
# Processing Record 12 of Set 12 | forster
# Processing Record 13 of Set 12 | trairi
# Processing Record 14 of Set 12 | lilongwe
# Processing Record 15 of Set 12 | bathsheba
# Processing Record 16 of Set 12 | martapura
# Processing Record 17 of Set 12 | cape canaveral
# Processing Record 18 of Set 12 | shihezi
# Processing Record 19 of Set 12 | guadalupe victoria
# Processing Record 20 of Set 12 | prineville
# Processing Record 21 of Set 12 | kavaratti
# Processing Record 22 of Set 12 | at taj
# Processing Record 23 of Set 12 | tubarjal
# Processing Record 24 of Set 12 | cedral
# Processing Record 25 of Set 12 | blenheim
# Processing Record 26 of Set 12 | lata
# Processing Record 27 of Set 12 | na klang
# Processing Record 28 of Set 12 | port shepstone
# Processing Record 29 of Set 12 | eagle point
# Processing Record 30 of Set 12 | malanje
# Processing Record 31 of Set 12 | gordes
# Processing Record 32 of Set 12 | abraham's bay
# City not found. Skipping...
# Processing Record 33 of Set 12 | jatiroto
# Processing Record 34 of Set 12 | gaigeturi
# Processing Record 35 of Set 12 | carloforte
# Processing Record 36 of Set 12 | sechura
# Processing Record 37 of Set 12 | katsuren-haebaru
# Processing Record 38 of Set 12 | beyneu
# Processing Record 39 of Set 12 | balqash
# Processing Record 40 of Set 12 | plastun
# Processing Record 41 of Set 12 | yorkton
# Processing Record 42 of Set 12 | tommot
# Processing Record 43 of Set 12 | margate
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       longyearbyen  78.2186   15.6401      9.91        81          75
# 1      port mathurin -19.6833   63.4167     21.68        73         100
# 2           waitangi -43.9535 -176.5597     12.68        97         100
# 3        west island -12.1568   96.8225     25.99        94          75
# 4  port-aux-francais -49.3500   70.2167      2.67        93         100
#
#    Wind Speed Country        Date
# 0        6.17      SJ  1724548471
# 1       10.93      MU  1724548472
# 2        2.68      NZ  1724548465
# 3        6.69      CC  1724548474
# 4       16.80      TF  1724548475

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label = "City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col = "City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             longyearbyen  78.2186   15.6401      9.91        81          75
# 1            port mathurin -19.6833   63.4167     21.68        73         100
# 2                 waitangi -43.9535 -176.5597     12.68        97         100
# 3              west island -12.1568   96.8225     25.99        94          75
# 4        port-aux-francais -49.3500   70.2167      2.67        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      SJ  1724548471
# 1             10.93      MU  1724548472
# 2              2.68      NZ  1724548465
# 3              6.69      CC  1724548474
# 4             16.80      TF  1724548475

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], 
            city_data_df["Max Temp"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind Speed"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, coordinates):
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Define regression values
    regress_values = x_values * slope + intercept

    # Create line equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Annotate linear equation
    plt.annotate(line_eq, coordinates, fontsize = 15, color = "red")
    
    # Create scatter plot
    plt.scatter(x_values, y_values, color = "blue", alpha = 0.8, edgecolor = "black")
    
    # Create regression line
    plt.plot(x_values, regress_values, "r-")   
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f'{x_label} vs {y_label}')

    # Print r-squared value
    print(f"The r-squared is: {r_value**2}")
 
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        longyearbyen  78.2186  15.6401      9.91        81          75
# 5                argo  37.6333  22.7333     26.96        44          11
# 10            alesund  62.4723   6.1549     14.31        88         100
# 11           thompson  55.7435 -97.8558     20.68        62          86
# 12             bethel  41.3712 -73.4140     21.40        82          20
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      SJ  1724548471
# 5              1.94      GR  1724548476
# 10             1.03      NO  1724548482
# 11             2.79      CA  1724548483
# 12             2.06      US  1724548254

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            port mathurin -19.6833   63.4167     21.68        73         100
# 2                 waitangi -43.9535 -176.5597     12.68        97         100
# 3              west island -12.1568   96.8225     25.99        94          75
# 4        port-aux-francais -49.3500   70.2167      2.67        93         100
# 6                papatowai -46.5619  169.4708      7.88        77         100
#
#          Wind Speed Country        Date
# City_ID
# 1             10.93      MU  1724548472
# 2              2.68      NZ  1724548465
# 3              6.69      CC  1724548474
# 4             16.80      TF  1724548475
# 6              1.49      NZ  1724548477

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Max Temp"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Max Temp" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (8, 5)) # Run function defined above
# Out:
# The r-squared is: 0.5630486074722731

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp (C)"

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 28))
# Out:
# The r-squared is: 0.5333257121489248

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the inverse linear relationships between latitude and maximum temperature (C) for the northern (top) and southern (bottom) hemispheres. Results show that, in the northern hemisphere, the maximum temperature decreases as latitude increases and moves away from the Equator (latitude = 0) and closer to Earth's North Pole. In contrast, the maximum temperature increases in the southern hemisphere as latitude gets closer to the Equator (latitude = 0) and moves away from Earth's South Pole. While the r-squared values indicate that the correlations can fluctuate between moderate to high for both hemispheres, the linear regressions indicate a relationship (positive and negative) between latitude and maximum temperature that is dependent on the hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Humidity"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Humidity (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (45, 10)) # Run function defined above
# Out:
# The r-squared is: 3.571541763151181e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Humidity"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Humidity (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 25)) # Run function defined above
# Out:
# The r-squared is: 0.03437048286517023

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude and humidity (%) for the northern (top) and southern (bottom) hemispheres. Interestingly, results show no specific relationship between latitude and percent humidity in the northern and southern hemispheres, as shown with the low slope and r-squared values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Cloudiness"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Cloudiness (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (50, 20)) # Run function defined above
# Out:
# The r-squared is: 0.0009034533756985038

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Cloudiness"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Cloudiness (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 20)) # Run function defined above
# Out:
# The r-squared is: 0.06800927305099394

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude and cloudiness (%) for the northern (top) and southern (bottom) hemispheres. As with percent humidity, results show no specific relationship between latitude and percent cloudiness in the northern and southern hemispheres, as shown with the low slope and r-squared values.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Wind Speed"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Wind Speed (m/s)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (5, 12)) # Run function defined above
# Out:
# The r-squared is: 0.0021272513378051867

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Wind Speed"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Wind Speed (m/s)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 17.5)) # Run function defined above
# Out:
# The r-squared is: 2.934313138165654e-06

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude and wind speed (m/s) for the northern (top) and southern (bottom) hemispheres. As with percent humidity and cloudiness, results show no specific relationship between latitude and wind speed in the northern and southern hemispheres, as shown with the low slope and r-squared values.
