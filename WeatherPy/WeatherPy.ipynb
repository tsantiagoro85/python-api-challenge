# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 571

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = {"q": city, "units": "metric", "APPID": weather_api_key}

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url, params = city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gadzhiyevo
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | huazhou
# Processing Record 4 of Set 1 | wanning
# Processing Record 5 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 1 | torremaggiore
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | blackmans bay
# Processing Record 11 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | olonkinbyen
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hirara
# Processing Record 17 of Set 1 | isafjordur
# Processing Record 18 of Set 1 | krasnaya polyana
# Processing Record 19 of Set 1 | qamdo
# Processing Record 20 of Set 1 | waitangi
# Processing Record 21 of Set 1 | kailua-kona
# Processing Record 22 of Set 1 | xining
# Processing Record 23 of Set 1 | chita
# Processing Record 24 of Set 1 | karimganj
# Processing Record 25 of Set 1 | keflavik
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | concepcion
# Processing Record 28 of Set 1 | puerto natales
# Processing Record 29 of Set 1 | baramula
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | fort st. john
# Processing Record 32 of Set 1 | khandyga
# Processing Record 33 of Set 1 | la'ie
# Processing Record 34 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | invercargill
# Processing Record 37 of Set 1 | nakambala
# Processing Record 38 of Set 1 | st. john's
# Processing Record 39 of Set 1 | grand rapids
# Processing Record 40 of Set 1 | savave village
# City not found. Skipping...
# Processing Record 41 of Set 1 | vernon
# Processing Record 42 of Set 1 | binghamton
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | ubinskoye
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | minas de marcona
# Processing Record 47 of Set 1 | nova sintra
# Processing Record 48 of Set 1 | chemolgan
# Processing Record 49 of Set 1 | whitehorse
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | pontasserchio
# Processing Record 1 of Set 2 | mariental
# Processing Record 2 of Set 2 | dudinka
# Processing Record 3 of Set 2 | vilyuchinsk
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | ilulissat
# Processing Record 7 of Set 2 | espargos
# City not found. Skipping...
# Processing Record 8 of Set 2 | happy valley-goose bay
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | manacapuru
# Processing Record 11 of Set 2 | tazovsky
# Processing Record 12 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | margaret river
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | mammoth lakes
# Processing Record 17 of Set 2 | tura
# Processing Record 18 of Set 2 | santana
# Processing Record 19 of Set 2 | drama
# Processing Record 20 of Set 2 | tamanrasset
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | revda
# Processing Record 24 of Set 2 | torit
# Processing Record 25 of Set 2 | rosarito
# Processing Record 26 of Set 2 | chonchi
# Processing Record 27 of Set 2 | severo-yeniseyskiy
# Processing Record 28 of Set 2 | puerto cortez
# Processing Record 29 of Set 2 | papatowai
# Processing Record 30 of Set 2 | mankachar
# Processing Record 31 of Set 2 | north bend
# Processing Record 32 of Set 2 | edinburgh of the seven seas
# Processing Record 33 of Set 2 | amalapuram
# Processing Record 34 of Set 2 | el granada
# Processing Record 35 of Set 2 | illizi
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | bubaque
# Processing Record 39 of Set 2 | weihai
# Processing Record 40 of Set 2 | nuuk
# Processing Record 41 of Set 2 | itaituba
# Processing Record 42 of Set 2 | nicoya
# Processing Record 43 of Set 2 | benjamin constant
# Processing Record 44 of Set 2 | kapuskasing
# Processing Record 45 of Set 2 | san fernando
# Processing Record 46 of Set 2 | westport
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | saint-francois
# Processing Record 49 of Set 2 | dubbo
# Processing Record 0 of Set 3 | ankazoabo
# Processing Record 1 of Set 3 | ad dilam
# Processing Record 2 of Set 3 | ust-nera
# Processing Record 3 of Set 3 | bueno brandao
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 3 | luwuk
# Processing Record 7 of Set 3 | polyarnyy
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | bargara
# City not found. Skipping...
# Processing Record 10 of Set 3 | puerto baquerizo moreno
# Processing Record 11 of Set 3 | antsiranana
# Processing Record 12 of Set 3 | udachny
# Processing Record 13 of Set 3 | kulhudhuffushi
# Processing Record 14 of Set 3 | paciran
# Processing Record 15 of Set 3 | lhokseumawe
# Processing Record 16 of Set 3 | west island
# Processing Record 17 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 3 | tofol
# Processing Record 19 of Set 3 | pangoa
# Processing Record 20 of Set 3 | korla
# Processing Record 21 of Set 3 | mobaye
# Processing Record 22 of Set 3 | aasiaat
# Processing Record 23 of Set 3 | mundri
# Processing Record 24 of Set 3 | nar'yan-mar
# Processing Record 25 of Set 3 | qaqortoq
# Processing Record 26 of Set 3 | launceston
# Processing Record 27 of Set 3 | saipan
# Processing Record 28 of Set 3 | saint george's
# Processing Record 29 of Set 3 | tiksi
# Processing Record 30 of Set 3 | roma
# Processing Record 31 of Set 3 | thinadhoo
# Processing Record 32 of Set 3 | ca mau
# Processing Record 33 of Set 3 | pathein
# Processing Record 34 of Set 3 | flying fish cove
# Processing Record 35 of Set 3 | lata
# Processing Record 36 of Set 3 | iskateley
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | dakhla
# Processing Record 39 of Set 3 | fada
# Processing Record 40 of Set 3 | afaahiti
# Processing Record 41 of Set 3 | harstad
# Processing Record 42 of Set 3 | colonia
# Processing Record 43 of Set 3 | barreiro do jaiba
# Processing Record 44 of Set 3 | gambiran satu
# Processing Record 45 of Set 3 | teno
# Processing Record 46 of Set 3 | tayu
# Processing Record 47 of Set 3 | la passe
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | nemuro
# Processing Record 0 of Set 4 | anadyr
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | piti village
# Processing Record 3 of Set 4 | bugene
# Processing Record 4 of Set 4 | haiku-pauwela
# Processing Record 5 of Set 4 | nagqu
# Processing Record 6 of Set 4 | souq larb'a al gharb
# Processing Record 7 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 8 of Set 4 | dunay
# Processing Record 9 of Set 4 | cambridge
# Processing Record 10 of Set 4 | stanley
# Processing Record 11 of Set 4 | uyar
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | quellon
# Processing Record 14 of Set 4 | uturoa
# Processing Record 15 of Set 4 | primorskiy
# Processing Record 16 of Set 4 | kutum
# Processing Record 17 of Set 4 | ba
# City not found. Skipping...
# Processing Record 18 of Set 4 | talnakh
# Processing Record 19 of Set 4 | san antonio de pale
# Processing Record 20 of Set 4 | yelizovo
# Processing Record 21 of Set 4 | nova xavantina
# Processing Record 22 of Set 4 | upper sandusky
# Processing Record 23 of Set 4 | papao
# Processing Record 24 of Set 4 | estremoz
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | cadale
# Processing Record 27 of Set 4 | howard springs
# Processing Record 28 of Set 4 | ulladulla
# Processing Record 29 of Set 4 | pasargad
# City not found. Skipping...
# Processing Record 30 of Set 4 | ponta delgada
# Processing Record 31 of Set 4 | mitu
# Processing Record 32 of Set 4 | pyhajarvi
# Processing Record 33 of Set 4 | alofi
# Processing Record 34 of Set 4 | kisangani
# Processing Record 35 of Set 4 | queenstown
# Processing Record 36 of Set 4 | badger
# Processing Record 37 of Set 4 | lycksele
# Processing Record 38 of Set 4 | sola
# Processing Record 39 of Set 4 | ozark
# Processing Record 40 of Set 4 | susuman
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | hamilton
# Processing Record 43 of Set 4 | afif
# Processing Record 44 of Set 4 | bayanhongor
# Processing Record 45 of Set 4 | timbuktu
# Processing Record 46 of Set 4 | nieuw amsterdam
# Processing Record 47 of Set 4 | pemangkat
# Processing Record 48 of Set 4 | klyuchi
# Processing Record 49 of Set 4 | sabi
# Processing Record 0 of Set 5 | sechura
# Processing Record 1 of Set 5 | crane
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | midvagur
# Processing Record 4 of Set 5 | bhabhua
# Processing Record 5 of Set 5 | taltal
# Processing Record 6 of Set 5 | port mathurin
# Processing Record 7 of Set 5 | saint-joseph
# Processing Record 8 of Set 5 | kirillov
# Processing Record 9 of Set 5 | hawaiian paradise park
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | kuala belait
# Processing Record 12 of Set 5 | hotan
# Processing Record 13 of Set 5 | umea
# Processing Record 14 of Set 5 | sandnessjoen
# Processing Record 15 of Set 5 | bereeda
# Processing Record 16 of Set 5 | lanzhou
# Processing Record 17 of Set 5 | sydney
# Processing Record 18 of Set 5 | ailuk
# Processing Record 19 of Set 5 | dwarka
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | vorgashor
# Processing Record 22 of Set 5 | atherton
# Processing Record 23 of Set 5 | krasnyy chikoy
# Processing Record 24 of Set 5 | kalemie
# Processing Record 25 of Set 5 | rio preto da eva
# Processing Record 26 of Set 5 | hadibu
# Processing Record 27 of Set 5 | ushuaia
# Processing Record 28 of Set 5 | ikalamavony
# Processing Record 29 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 30 of Set 5 | murray bridge
# Processing Record 31 of Set 5 | bam
# Processing Record 32 of Set 5 | tangalle
# Processing Record 33 of Set 5 | bauru
# Processing Record 34 of Set 5 | ust'-kulom
# Processing Record 35 of Set 5 | atafu village
# Processing Record 36 of Set 5 | praia da vitoria
# Processing Record 37 of Set 5 | yatou
# Processing Record 38 of Set 5 | punta arenas
# Processing Record 39 of Set 5 | alekseyevskoye
# Processing Record 40 of Set 5 | kiselevsk
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | puerto ayacucho
# Processing Record 43 of Set 5 | benalla
# Processing Record 44 of Set 5 | kaya
# Processing Record 45 of Set 5 | peace river
# Processing Record 46 of Set 5 | san jose del cabo
# Processing Record 47 of Set 5 | jabal os saraj
# Processing Record 48 of Set 5 | selfoss
# Processing Record 49 of Set 5 | east london
# Processing Record 0 of Set 6 | boyolangu
# Processing Record 1 of Set 6 | siocon
# Processing Record 2 of Set 6 | pemba
# Processing Record 3 of Set 6 | amga
# Processing Record 4 of Set 6 | mwinilunga
# Processing Record 5 of Set 6 | calvinia
# Processing Record 6 of Set 6 | kerikeri
# Processing Record 7 of Set 6 | fortuna
# Processing Record 8 of Set 6 | egilsstadir
# Processing Record 9 of Set 6 | taguatinga
# Processing Record 10 of Set 6 | kovalam
# Processing Record 11 of Set 6 | balikpapan
# Processing Record 12 of Set 6 | corner brook
# Processing Record 13 of Set 6 | mount pleasant
# Processing Record 14 of Set 6 | dzhalagash
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | howrah
# Processing Record 17 of Set 6 | kingston
# Processing Record 18 of Set 6 | namibe
# Processing Record 19 of Set 6 | brisas de zicatela
# Processing Record 20 of Set 6 | vila franca do campo
# Processing Record 21 of Set 6 | tolanaro
# Processing Record 22 of Set 6 | antofagasta
# Processing Record 23 of Set 6 | chinde
# Processing Record 24 of Set 6 | ennis
# Processing Record 25 of Set 6 | pantai cenang
# City not found. Skipping...
# Processing Record 26 of Set 6 | kirakira
# Processing Record 27 of Set 6 | belmonte
# Processing Record 28 of Set 6 | huarmey
# Processing Record 29 of Set 6 | tromso
# Processing Record 30 of Set 6 | constantia
# Processing Record 31 of Set 6 | progreso
# Processing Record 32 of Set 6 | port saint john's
# Processing Record 33 of Set 6 | georgetown
# Processing Record 34 of Set 6 | kodiak
# Processing Record 35 of Set 6 | holualoa
# Processing Record 36 of Set 6 | bardai
# Processing Record 37 of Set 6 | colonia menno
# Processing Record 38 of Set 6 | imphal
# Processing Record 39 of Set 6 | lebedyan'
# Processing Record 40 of Set 6 | coxim
# Processing Record 41 of Set 6 | birjand
# Processing Record 42 of Set 6 | mil'kovo
# Processing Record 43 of Set 6 | sao jose da coroa grande
# Processing Record 44 of Set 6 | cururupu
# Processing Record 45 of Set 6 | sishilichengzi
# City not found. Skipping...
# Processing Record 46 of Set 6 | lakatoro
# Processing Record 47 of Set 6 | topeka
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | necochea
# Processing Record 0 of Set 7 | mata-utu
# Processing Record 1 of Set 7 | udgir
# Processing Record 2 of Set 7 | lenger
# Processing Record 3 of Set 7 | sinabang
# Processing Record 4 of Set 7 | januaria
# Processing Record 5 of Set 7 | aykhal
# Processing Record 6 of Set 7 | arkhangel'sk
# Processing Record 7 of Set 7 | tazacorte
# Processing Record 8 of Set 7 | mukalla
# Processing Record 9 of Set 7 | itirucu
# Processing Record 10 of Set 7 | taro
# Processing Record 11 of Set 7 | tralee
# Processing Record 12 of Set 7 | suntar
# Processing Record 13 of Set 7 | padam
# City not found. Skipping...
# Processing Record 14 of Set 7 | kendari
# Processing Record 15 of Set 7 | rochester
# Processing Record 16 of Set 7 | wailua homesteads
# Processing Record 17 of Set 7 | tucuma
# Processing Record 18 of Set 7 | chibougamau
# Processing Record 19 of Set 7 | remire-montjoly
# Processing Record 20 of Set 7 | rongelap
# Processing Record 21 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 22 of Set 7 | cedeira
# Processing Record 23 of Set 7 | tevragh zeina
# City not found. Skipping...
# Processing Record 24 of Set 7 | magadan
# Processing Record 25 of Set 7 | ola
# Processing Record 26 of Set 7 | nuku'alofa
# Processing Record 27 of Set 7 | surendranagar
# Processing Record 28 of Set 7 | newman
# Processing Record 29 of Set 7 | chebba
# Processing Record 30 of Set 7 | ceeldheer
# Processing Record 31 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 7 | fale old settlement
# Processing Record 33 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 34 of Set 7 | karratha
# Processing Record 35 of Set 7 | parksville
# Processing Record 36 of Set 7 | bensonville
# Processing Record 37 of Set 7 | kanazawa
# Processing Record 38 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 39 of Set 7 | kiunga
# Processing Record 40 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 41 of Set 7 | esmeralda
# Processing Record 42 of Set 7 | beyneu
# Processing Record 43 of Set 7 | hemsby
# Processing Record 44 of Set 7 | kemijarvi
# Processing Record 45 of Set 7 | sitka
# Processing Record 46 of Set 7 | dawson creek
# Processing Record 47 of Set 7 | gorshechnoye
# Processing Record 48 of Set 7 | utrik
# Processing Record 49 of Set 7 | siracusa
# Processing Record 0 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 1 of Set 8 | aldama
# Processing Record 2 of Set 8 | basco
# Processing Record 3 of Set 8 | cam ranh
# Processing Record 4 of Set 8 | holzminden
# Processing Record 5 of Set 8 | pasuquin
# Processing Record 6 of Set 8 | calama
# Processing Record 7 of Set 8 | vadso
# Processing Record 8 of Set 8 | strzegom
# Processing Record 9 of Set 8 | kamianske
# Processing Record 10 of Set 8 | altai
# Processing Record 11 of Set 8 | xinyuan
# Processing Record 12 of Set 8 | gaspe
# Processing Record 13 of Set 8 | borodino
# Processing Record 14 of Set 8 | alotau
# Processing Record 15 of Set 8 | inhambane
# Processing Record 16 of Set 8 | laojunmiao
# Processing Record 17 of Set 8 | guerrero negro
# Processing Record 18 of Set 8 | allapalli
# Processing Record 19 of Set 8 | chaozhou
# Processing Record 20 of Set 8 | wotho
# Processing Record 21 of Set 8 | isangel
# Processing Record 22 of Set 8 | villa gesell
# Processing Record 23 of Set 8 | mundybash
# Processing Record 24 of Set 8 | zaigrayevo
# Processing Record 25 of Set 8 | yigo village
# Processing Record 26 of Set 8 | bikenibeu village
# Processing Record 27 of Set 8 | nyurba
# Processing Record 28 of Set 8 | pasni
# Processing Record 29 of Set 8 | kingsland
# Processing Record 30 of Set 8 | rabo de peixe
# Processing Record 31 of Set 8 | poblacion, san felipe
# Processing Record 32 of Set 8 | saint-pierre
# Processing Record 33 of Set 8 | kourou
# Processing Record 34 of Set 8 | wewak
# Processing Record 35 of Set 8 | zaozersk
# Processing Record 36 of Set 8 | labasa
# Processing Record 37 of Set 8 | mollendo
# Processing Record 38 of Set 8 | maputo
# Processing Record 39 of Set 8 | akureyri
# Processing Record 40 of Set 8 | ketchikan
# Processing Record 41 of Set 8 | groveport
# Processing Record 42 of Set 8 | shenjiamen
# Processing Record 43 of Set 8 | key west
# Processing Record 44 of Set 8 | goba
# Processing Record 45 of Set 8 | labytnangi
# Processing Record 46 of Set 8 | mayya
# Processing Record 47 of Set 8 | diamantina
# Processing Record 48 of Set 8 | nova vicosa
# Processing Record 49 of Set 8 | labuan
# Processing Record 0 of Set 9 | codrington
# Processing Record 1 of Set 9 | ad dawadimi
# Processing Record 2 of Set 9 | shuangjiang
# Processing Record 3 of Set 9 | brookings
# Processing Record 4 of Set 9 | novyy turtkul'
# Processing Record 5 of Set 9 | presidente dutra
# Processing Record 6 of Set 9 | angaur state
# Processing Record 7 of Set 9 | ivisan
# Processing Record 8 of Set 9 | oriximina
# Processing Record 9 of Set 9 | helena valley southeast
# Processing Record 10 of Set 9 | arapgir
# Processing Record 11 of Set 9 | virginia beach
# Processing Record 12 of Set 9 | kholmsk
# Processing Record 13 of Set 9 | grande prairie
# Processing Record 14 of Set 9 | kangding
# Processing Record 15 of Set 9 | governor's harbour
# City not found. Skipping...
# Processing Record 16 of Set 9 | coronel suarez
# Processing Record 17 of Set 9 | ghadamis
# Processing Record 18 of Set 9 | coquimbo
# Processing Record 19 of Set 9 | pitimbu
# Processing Record 20 of Set 9 | pueblo nuevo
# Processing Record 21 of Set 9 | pula
# Processing Record 22 of Set 9 | hilo
# Processing Record 23 of Set 9 | general acha
# Processing Record 24 of Set 9 | new norfolk
# Processing Record 25 of Set 9 | tottori
# Processing Record 26 of Set 9 | filey
# Processing Record 27 of Set 9 | lesnoy
# Processing Record 28 of Set 9 | hithadhoo
# Processing Record 29 of Set 9 | caleta de carquin
# Processing Record 30 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 31 of Set 9 | flin flon
# Processing Record 32 of Set 9 | fandrandava
# Processing Record 33 of Set 9 | fisterra
# Processing Record 34 of Set 9 | juneau
# Processing Record 35 of Set 9 | nellore
# Processing Record 36 of Set 9 | cabinda
# Processing Record 37 of Set 9 | shanhecun
# Processing Record 38 of Set 9 | marka
# Processing Record 39 of Set 9 | portoferraio
# Processing Record 40 of Set 9 | jinhua
# Processing Record 41 of Set 9 | washougal
# Processing Record 42 of Set 9 | praya
# Processing Record 43 of Set 9 | prince george
# Processing Record 44 of Set 9 | fort mcmurray
# Processing Record 45 of Set 9 | enewetak
# Processing Record 46 of Set 9 | grootfontein
# Processing Record 47 of Set 9 | kapa'a
# Processing Record 48 of Set 9 | paraiso
# Processing Record 49 of Set 9 | kem'
# Processing Record 0 of Set 10 | wynyard
# Processing Record 1 of Set 10 | mercedes
# Processing Record 2 of Set 10 | yamba
# City not found. Skipping...
# Processing Record 3 of Set 10 | shubarkuduk
# Processing Record 4 of Set 10 | kone
# Processing Record 5 of Set 10 | zabol
# Processing Record 6 of Set 10 | glazov
# Processing Record 7 of Set 10 | serowe
# Processing Record 8 of Set 10 | lethem
# Processing Record 9 of Set 10 | hunchun
# Processing Record 10 of Set 10 | manbij
# Processing Record 11 of Set 10 | saynshand
# Processing Record 12 of Set 10 | juegang
# Processing Record 13 of Set 10 | buncrana
# Processing Record 14 of Set 10 | posto fiscal rolim de moura
# Processing Record 15 of Set 10 | selkirk
# Processing Record 16 of Set 10 | saudarkrokur
# Processing Record 17 of Set 10 | trail
# Processing Record 18 of Set 10 | mkushi
# Processing Record 19 of Set 10 | conceicao da barra
# Processing Record 20 of Set 10 | tashtagol
# Processing Record 21 of Set 10 | mochudi
# Processing Record 22 of Set 10 | qarazhal
# Processing Record 23 of Set 10 | bel ombre
# Processing Record 24 of Set 10 | klaksvik
# Processing Record 25 of Set 10 | gorontalo
# Processing Record 26 of Set 10 | lihue
# Processing Record 27 of Set 10 | ta`u
# Processing Record 28 of Set 10 | malone
# Processing Record 29 of Set 10 | kuching
# Processing Record 30 of Set 10 | casper
# Processing Record 31 of Set 10 | san luis de la loma
# Processing Record 32 of Set 10 | ar ruways
# Processing Record 33 of Set 10 | terme
# Processing Record 34 of Set 10 | lang suan
# Processing Record 35 of Set 10 | tidjikja
# Processing Record 36 of Set 10 | boguchany
# Processing Record 37 of Set 10 | hammerfest
# Processing Record 38 of Set 10 | fomboni
# Processing Record 39 of Set 10 | lospalos
# Processing Record 40 of Set 10 | phan thiet
# Processing Record 41 of Set 10 | taroudant
# Processing Record 42 of Set 10 | benjamin aceval
# Processing Record 43 of Set 10 | fallon
# Processing Record 44 of Set 10 | laminusa
# Processing Record 45 of Set 10 | ghat
# Processing Record 46 of Set 10 | knyaze-volkonskoye
# Processing Record 47 of Set 10 | hosa'ina
# City not found. Skipping...
# Processing Record 48 of Set 10 | kouango
# Processing Record 49 of Set 10 | swakopmund
# Processing Record 0 of Set 11 | mary
# Processing Record 1 of Set 11 | dosso
# Processing Record 2 of Set 11 | berezovyy
# Processing Record 3 of Set 11 | bilajer
# Processing Record 4 of Set 11 | eskisehir
# Processing Record 5 of Set 11 | yuzhno-kurilsk
# Processing Record 6 of Set 11 | krasnyy yar
# Processing Record 7 of Set 11 | mana
# Processing Record 8 of Set 11 | korba
# Processing Record 9 of Set 11 | figeac
# Processing Record 10 of Set 11 | sisimiut
# Processing Record 11 of Set 11 | mutoko
# Processing Record 12 of Set 11 | vilyuysk
# Processing Record 13 of Set 11 | muroto-misakicho
# Processing Record 14 of Set 11 | fuling
# Processing Record 15 of Set 11 | olyokminsk
# Processing Record 16 of Set 11 | qionghai
# Processing Record 17 of Set 11 | conception bay south
# Processing Record 18 of Set 11 | padang
# Processing Record 19 of Set 11 | weno
# Processing Record 20 of Set 11 | kultali
# City not found. Skipping...
# Processing Record 21 of Set 11 | bonthe
# Processing Record 22 of Set 11 | apucarana
# Processing Record 23 of Set 11 | merizo village
# Processing Record 24 of Set 11 | badagry
# Processing Record 25 of Set 11 | uray
# Processing Record 26 of Set 11 | outjo
# Processing Record 27 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 11 | columbia falls
# Processing Record 29 of Set 11 | fuglafjordur
# Processing Record 30 of Set 11 | yaren
# Processing Record 31 of Set 11 | mossel bay
# Processing Record 32 of Set 11 | la palma
# Processing Record 33 of Set 11 | koryazhma
# Processing Record 34 of Set 11 | phongsali
# Processing Record 35 of Set 11 | concepcion del oro
# Processing Record 36 of Set 11 | argo
# Processing Record 37 of Set 11 | chacabuco
# Processing Record 38 of Set 11 | suva
# Processing Record 39 of Set 11 | veinticinco de mayo
# Processing Record 40 of Set 11 | kununurra
# Processing Record 41 of Set 11 | kauhava
# Processing Record 42 of Set 11 | as sulayyil
# Processing Record 43 of Set 11 | karlshamn
# Processing Record 44 of Set 11 | houlton
# Processing Record 45 of Set 11 | liepaja
# Processing Record 46 of Set 11 | al mayadin
# Processing Record 47 of Set 11 | san andres
# Processing Record 48 of Set 11 | wanxian
# Processing Record 49 of Set 11 | ciudad bolivar
# Processing Record 0 of Set 12 | inekar
# City not found. Skipping...
# Processing Record 1 of Set 12 | yartsevo
# Processing Record 2 of Set 12 | vyskov
# Processing Record 3 of Set 12 | kingscliff
# Processing Record 4 of Set 12 | mahibadhoo
# Processing Record 5 of Set 12 | port-vila
# Processing Record 6 of Set 12 | baruun-urt
# Processing Record 7 of Set 12 | orapa
# Processing Record 8 of Set 12 | thurso
# Processing Record 9 of Set 12 | pimenta bueno
# Processing Record 10 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 12 | baturaja
# Processing Record 12 of Set 12 | marsh harbour
# Processing Record 13 of Set 12 | westerland
# Processing Record 14 of Set 12 | miranda
# Processing Record 15 of Set 12 | choyr
# Processing Record 16 of Set 12 | mount pearl
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | amble
# Processing Record 19 of Set 12 | igarka
# Processing Record 20 of Set 12 | balakhta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Cloudiness    541
# Wind Speed    541
# Country       541
# Date          541
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     gadzhiyevo  69.2551   33.3362     14.93        58          89
# 1     bredasdorp -34.5322   20.0403      9.36        86          99
# 2        huazhou  21.6333  110.5833     27.35        80           6
# 3        wanning  18.8003  110.3967     27.86        84          56
# 4  torremaggiore  41.6907   15.2963     31.69        47          88
#
#    Wind Speed Country        Date
# 0       12.07      RU  1724767818
# 1       11.27      ZA  1724767819
# 2        2.73      CN  1724767821
# 3        1.94      CN  1724767822
# 4        7.85      IT  1724767824

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label = "City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col = "City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           gadzhiyevo  69.2551   33.3362     14.93        58          89
# 1           bredasdorp -34.5322   20.0403      9.36        86          99
# 2              huazhou  21.6333  110.5833     27.35        80           6
# 3              wanning  18.8003  110.3967     27.86        84          56
# 4        torremaggiore  41.6907   15.2963     31.69        47          88
#
#          Wind Speed Country        Date
# City_ID
# 0             12.07      RU  1724767818
# 1             11.27      ZA  1724767819
# 2              2.73      CN  1724767821
# 3              1.94      CN  1724767822
# 4              7.85      IT  1724767824

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], 
            city_data_df["Max Temp"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], 
            city_data_df["Humidity"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], 
            city_data_df["Cloudiness"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], 
            city_data_df["Wind Speed"], 
            edgecolor = "black", 
            linewidths = 1, 
            marker = "o", 
            alpha = 0.8, 
            label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, coordinates):
    # Perform linear regression
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Define regression values
    regress_values = x_values * slope + intercept

    # Create line equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Annotate linear equation
    plt.annotate(line_eq, coordinates, fontsize = 15, color = "red")
    
    # Create scatter plot
    plt.scatter(x_values, y_values, color = "blue", alpha = 0.8, edgecolor = "black")
    
    # Create regression line
    plt.plot(x_values, regress_values, "r-")   
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f'{x_label} vs {y_label}')

    # Print r-squared value
    print(f"The r-squared is: {r_value**2}")
 
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           gadzhiyevo  69.2551   33.3362     14.93        58          89
# 2              huazhou  21.6333  110.5833     27.35        80           6
# 3              wanning  18.8003  110.3967     27.86        84          56
# 4        torremaggiore  41.6907   15.2963     31.69        47          88
# 9              college  64.8569 -147.8028      8.58        86          75
#
#          Wind Speed Country        Date
# City_ID
# 0             12.07      RU  1724767818
# 2              2.73      CN  1724767821
# 3              1.94      CN  1724767822
# 4              7.85      IT  1724767824
# 9              3.09      US  1724767831

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               bredasdorp -34.5322   20.0403      9.36        86          99
# 5                grytviken -54.2811  -36.5092      3.72        83          99
# 6                adamstown -25.0660 -130.1015     19.60        71         100
# 7        port-aux-francais -49.3500   70.2167      2.99        75           6
# 8            blackmans bay -43.0167  147.3167      7.07        92         100
#
#          Wind Speed Country        Date
# City_ID
# 1             11.27      ZA  1724767819
# 5              3.87      GS  1724767825
# 6              9.46      PN  1724767826
# 7              8.11      TF  1724767827
# 8              5.28      AU  1724767829

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Max Temp"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Max Temp" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (8, 5)) # Run function defined above
# Out:
# The r-squared is: 0.45007812355255544

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
x_label = "Latitude"
y_label = "Max Temp (C)"

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 28))
# Out:
# The r-squared is: 0.5604838500104736

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the inverse linear relationships between latitude (x-axis) and maximum temperature (C) (y-axis) for the northern (top) and southern (bottom) hemispheres. Results show that, in the northern hemisphere, the maximum temperature decreases as latitude increases and moves away from the Equator (latitude = 0) and closer to Earth's North Pole. In contrast, the maximum temperature increases in the southern hemisphere as latitude gets closer to the Equator (latitude = 0), and moves away from Earth's South Pole. While the r-squared values indicate that the correlations can fluctuate between moderate to high for both hemispheres, the linear regressions suggest a relationship (positive and negative) between latitude and maximum temperature that is dependent on the hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Humidity"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Humidity (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (45, 10)) # Run function defined above
# Out:
# The r-squared is: 0.000596387643966457

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Humidity"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Humidity (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 25)) # Run function defined above
# Out:
# The r-squared is: 0.0019459015662558472

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude (x-axis) and humidity (%) (y-axis) for the northern (top) and southern (bottom) hemispheres. Interestingly, results show no specific relationship between latitude and percent humidity in the northern and southern hemispheres, as shown with the low slope and r-squared values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Cloudiness"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Cloudiness (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (45, 22)) # Run function defined above
# Out:
# The r-squared is: 4.442432225349253e-05

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Cloudiness"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Cloudiness (%)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 15)) # Run function defined above
# Out:
# The r-squared is: 0.004159434071522087

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude (x-axis) and cloudiness (%) (y-axis) for the northern (top) and southern (bottom) hemispheres. As with percent humidity, results show no specific relationship between latitude and percent cloudiness in the northern and southern hemispheres, as shown with the low slope and r-squared values.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"] # Set x axis
y_values = northern_hemi_df["Wind Speed"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Wind Speed (m/s)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (5, 12)) # Run function defined above
# Out:
# The r-squared is: 0.005307648201525886

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"] # Set x axis
y_values = southern_hemi_df["Wind Speed"] # Set y axis
x_label = "Latitude" # Set x label
y_label = "Wind Speed (m/s)" # Set y label

create_linear_regression_plot(x_values, y_values, x_label, y_label, (-55, 17.5)) # Run function defined above
# Out:
# The r-squared is: 0.056078987190709556

# %% [markdown]
# **Discussion about the linear relationship:** The scatter plots  and the linear correlations above showcase the linear relationships between latitude (x-axis) and wind speed (m/s) (y-axis) for the northern (top) and southern (bottom) hemispheres. As with percent humidity and cloudiness, results show no specific relationship between latitude and wind speed in the northern and southern hemispheres, as shown with the low slope and r-squared values.

# %%
### END ###
